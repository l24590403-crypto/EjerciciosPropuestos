# %% [markdown]
# <a href="https://colab.research.google.com/github/l24590403-crypto/EjerciciosPropuestos/blob/main/Ejercicio4_CajeroBBVA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Cola:
    def __init__(self):
        self.items = []

    def enqueue(self, dato):
        self.items.append(dato)

    def dequeue(self):
        return self.items.pop(0) if not self.is_empty() else None

    def front(self):
        return self.items[0] if not self.is_empty() else None

    def is_empty(self):
        return len(self.items) == 0

    def clear(self):
        self.items = []

cola_banco = Cola()
opcion = 0

while opcion != 4:
    print(" - - - MENU PRINCIPAL - - -")
    print(f"Clientes en espera: {cola_banco.items}")
    print("1. Agregar cliente a la cola")
    print("2. Atender a todos los clientes")
    print("3. Eliminar la cola completa")
    print("4. Salir")

    try:
        opcion = int(input("Ingrese una opción: "))
    except ValueError:
        print("Error: Ingrese un número válido.")
        continue

    if opcion == 1:
        nombre = input("Ingrese el nombre del cliente: ")
        cola_banco.enqueue(nombre)
        print(f"Cliente '{nombre}' agregado a la cola.")

    elif opcion == 2:
        if cola_banco.is_empty():
            print("¿No hay clientes en la cola para atender.")
        else:
            print("\n--- Iniciando atención de clientes ---")
            while not cola_banco.is_empty():
                cliente_actual = cola_banco.front()
                print(f"\nPasando a atender a: {cliente_actual}")

                opcion2 = 0
                while opcion2 != 4:
                    print("\n  -- SUBMENU DE OPERACIONES --")
                    print(f"  Cliente: {cliente_actual}")
                    print("  1. Retirar")
                    print("  2. Depositar")
                    print("  3. Consultar saldo")
                    print("  4. Finalizar atención")

                    try:
                        opcion2 = int(input("  Ingrese una operación: "))
                    except ValueError:
                        print("  Error: Ingrese un número válido.")
                        continue

                    if opcion2 == 1:
                        print(f"Retiro exitoso para {cliente_actual}.")
                    elif opcion2 == 2:
                        print(f"Depósito exitoso para {cliente_actual}.")
                    elif opcion2 == 3:
                        print(f"Saldo consultado por {cliente_actual}.")
                    elif opcion2 == 4:
                        cliente_atendido = cola_banco.dequeue()
                        print(f"Cliente '{cliente_atendido}' atendido. Pasando al siguiente...")
                    else:
                        print("Opción de operación inválida.")

            print("\n--- Todos los clientes han sido atendidos. Volviendo al menú principal. ---")
    elif opcion == 3:
        cola_banco.clear()
        print("La cola de clientes ha sido eliminada.")

    elif opcion == 4:
        print("Saliendo del programa. ¡Hasta luego!")

    else:
        print("Opción inválida. Por favor, elija una opción del 1 al 4.")
# Out:
# ====================
#       MENU PRINCIPAL
# ====================
# Clientes en espera: []
# 1. Agregar cliente a la cola
# 2. Atender a todos los clientes
# 3. Eliminar la cola completa
# 4. Salir
# Ingrese una opción: 1
# Ingrese el nombre del cliente: Gael
# ✅ Cliente 'Gael' agregado a la cola.
#
# ====================
#       MENU PRINCIPAL
# ====================
# Clientes en espera: ['Gael']
# 1. Agregar cliente a la cola
# 2. Atender a todos los clientes
# 3. Eliminar la cola completa
# 4. Salir
# Ingrese una opción: 1
# Ingrese el nombre del cliente: Jona
# ✅ Cliente 'Jona' agregado a la cola.
#
# ====================
#       MENU PRINCIPAL
# ====================
# Clientes en espera: ['Gael', 'Jona']
# 1. Agregar cliente a la cola
# 2. Atender a todos los clientes
# 3. Eliminar la cola completa
# 4. Salir
# Ingrese una opción: 1
# Ingrese el nombre del cliente: Hugo
# ✅ Cliente 'Hugo' agregado a la cola.
#
# ====================
#       MENU PRINCIPAL
# ====================
# Clientes en espera: ['Gael', 'Jona', 'Hugo']
# 1. Agregar cliente a la cola
# 2. Atender a todos los clientes
# 3. Eliminar la cola completa
# 4. Salir
# Ingrese una opción: 1
# Ingrese el nombre del cliente: Efren
# ✅ Cliente 'Efren' agregado a la cola.
#
# ====================
#       MENU PRINCIPAL
# ====================
# Clientes en espera: ['Gael', 'Jona', 'Hugo', 'Efren']
# 1. Agregar cliente a la cola
# 2. Atender a todos los clientes
# 3. Eliminar la cola completa
# 4. Salir
# Ingrese una opción: 2
#
# --- Iniciando atención de clientes ---
#
# ▶️ Pasando a atender a: Gael
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Gael
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 1
#   💸 Retiro exitoso para Gael.
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Gael
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 2
#   💰 Depósito exitoso para Gael.
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Gael
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 3
#   🧾 Saldo consultado por Gael.
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Gael
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 4
# ✅ Cliente 'Gael' atendido. Pasando al siguiente...
#
# ▶️ Pasando a atender a: Jona
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Jona
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 1
#   💸 Retiro exitoso para Jona.
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Jona
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 2
#   💰 Depósito exitoso para Jona.
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Jona
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 4
# ✅ Cliente 'Jona' atendido. Pasando al siguiente...
#
# ▶️ Pasando a atender a: Hugo
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Hugo
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 3
#   🧾 Saldo consultado por Hugo.
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Hugo
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 4
# ✅ Cliente 'Hugo' atendido. Pasando al siguiente...
#
# ▶️ Pasando a atender a: Efren
#
#   -- SUBMENU DE OPERACIONES --
#   Cliente: Efren
#   1. Retirar
#   2. Depositar
#   3. Consultar saldo
#   4. Finalizar atención
#   Ingrese una operación: 4
# ✅ Cliente 'Efren' atendido. Pasando al siguiente...
#
# --- Todos los clientes han sido atendidos. Volviendo al menú principal. ---
#
# ====================
#       MENU PRINCIPAL
# ====================
# Clientes en espera: []
# 1. Agregar cliente a la cola
# 2. Atender a todos los clientes
# 3. Eliminar la cola completa
# 4. Salir
